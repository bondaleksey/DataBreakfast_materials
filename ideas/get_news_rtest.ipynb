# %%
from gnews import GNews

# %%
google_news = GNews()
ai_news = google_news.get_news('AI')

# %%
len(ai_news)
# Out:
# 93

# %%
ai_news
# Out:
# [{'title': 'Can This A.I.-Powered Search Engine Replace Google? It Has for Me. - The New York Times',
#   'description': 'Can This A.I.-Powered Search Engine Replace Google? It Has for Me.  The New York Times',
#   'published date': 'Thu, 01 Feb 2024 10:00:43 GMT',
#   'url': 'https://news.google.com/rss/articles/CBMiTmh0dHBzOi8vd3d3Lm55dGltZXMuY29tLzIwMjQvMDIvMDEvdGVjaG5vbG9neS9wZXJwbGV4aXR5LXNlYXJjaC1haS1nb29nbGUuaHRtbNIBAA?oc=5&hl=en-US&gl=US&ceid=US:en',
#   'publisher': {'href': 'https://www.nytimes.com',
#    'title': 'The New York Times'}},
#  {'title': 'Mastercard jumps into generative AI race with model it says can boost fraud detection by up to 300% - CNBC',
#   'description': 'Mastercard jumps into generative AI race with model it says can boost fraud detection by up to 300%  CNBC',
#   'published date': 'Thu, 01 Feb 2024 06:00:31 GMT',
# ...

# %%
len(ai_news)
# Out:
# 97

# %%
ai_news
# Out:
# [{'title': 'Pakistan’s former leader Imran Khan sentenced to 14 years in prison, a day after being jailed for 10 years - CNN',
#   'description': 'Pakistan’s former leader Imran Khan sentenced to 14 years in prison, a day after being jailed for 10 years  CNNPakistani military use age-old tactics to keep Imran Khan away from election  The GuardianPakistan’s Imran Khan is in political ruin. He’s partly to blame  Al Jazeera English',
#   'published date': 'Wed, 31 Jan 2024 08:08:00 GMT',
#   'url': 'https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en',
#   'publisher': {'href': 'https://www.cnn.com', 'title': 'CNN'}},
# ...

# %%
from GoogleNews import GoogleNews
googlenews = GoogleNews()

# %%
print(googlenews.getVersion())
# Out:
# 1.6.12

# %%
googlenews.set_lang('en')
googlenews.set_period('7d')
#googlenews.set_time_range('01/25/2024','02/01/2024')
googlenews.set_encode('utf-8')

# %%
googlenews.search('AI')

# %%
result = googlenews.page_at(1)

# %%
result
# Out:
# [{'title': 'Donald Trump suggests mysterious red marks on hands may be AI-generated',
#   'media': 'Business Insider',
#   'date': '4 hours ago',
#   'datetime': datetime.datetime(2024, 2, 1, 14, 44, 59, 747637),
#   'desc': '',
#   'link': 'https://www.businessinsider.com/donald-trump-mysterious-red-marks-hand-may-be-ai-generated-2024-2&ved=2ahUKEwisjIOGvoqEAxXWrZUCHRjZBUoQxfQBegQIAxAC&usg=AOvVaw1vAIxrYjaTbnhmqvvdL7lA',
#   'img': '...'},
#  {'title': 'Video: A candidate targeted by a deepfake has an AI warning for America',
#   'media': 'CNN',
#   'date': '4 hours ago',
#   'datetime': datetime.datetime(2024, 2, 1, 14, 44, 59, 755219),
#   'desc': '',
#   'link': 'https://www.cnn.com/videos/business/2024/01/31/deepfake-ai-warnings-donie-osullivan-pkg-vpx.cnn&ved=2ahUKEwisjIOGvoqEAxXWrZUCHRjZBUoQxfQBegQICRAC&usg=AOvVaw3IiCq5YXb-tiBU1eWkU2-n',
#   'img': '...'},
# ...
